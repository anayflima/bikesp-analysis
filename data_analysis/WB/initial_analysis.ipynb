# %% [markdown]
# ## Taking a look at the data

# %%
import pandas as pd
import os

if 'WB' in os.getcwd():
    data_folder = '../../data/'
elif 'data_analysis' in os.getcwd():
    data_folder = '../data/'
else:
    data_folder = './data/'

source_folder_path = data_folder + 'WB/'
destination_folder_path = data_folder + 'WB/'

# %%
filename = 'SAO_PAULO_PREFERENCIA_DECLARADA_2021_BANCO_03.03.2022.csv'
data = pd.read_csv(source_folder_path + filename)

# %%
data.head()
# Out:
#    Ciclista - 1. Qual a sua idade?  \
# 0                               39
# 1                               24
# 2                               24
# 3                               17
# 4                               24
#
#   Ciclista - 1. Qual a sua idade? (Faixa etária)  \
# 0                          2. Entre 19 e 60 anos
# 1                          2. Entre 19 e 60 anos
# 2                          2. Entre 19 e 60 anos
# 3                                 1. Até 18 anos
# 4                          2. Entre 19 e 60 anos
#
#   Ciclista - 2. Com qual gênero você se identifica?  \
# 0                                      1. Masculino
# 1                                       2. Feminino
# 2                                       2. Feminino
# 3                                       2. Feminino
# 4                                       2. Feminino
#
#   Ciclista - 3. Qual a sua renda familiar? Ciclista - 4. Banheiro  \
# ...

# %%
for key in data.keys():
    print(key)
# Out:
# Ciclista - 1. Qual a sua idade?
# Ciclista - 1. Qual a sua idade? (Faixa etária)
# Ciclista - 2. Com qual gênero você se identifica?
# Ciclista - 3. Qual a sua renda familiar?
# Ciclista - 4. Banheiro
# Ciclista - 5. Empregado doméstico
# Ciclista - 6. Automóvel
# Ciclista - 7. Microcomputador
# Ciclista - 8. Lava louça
# Ciclista - 9. Geladeira
# Ciclista - 10. Freezer
# Ciclista - 11. Lava roupa
# Ciclista - 12. DVD
# Ciclista - 13. Microondas
# Ciclista - 14. Motocicleta
# Ciclista - 15. Secadora de roupas
# Ciclista - 16. Sua residência possui água encanada?
# Ciclista - 17. Sua residência possui rua pavimentada?
# Ciclista - 18. Qual o seu grau de instrução atual?
# Ciclista - Critério Brasil - Pontos
# Ciclista - Critério Brasil - Classe
# Ciclista - Ciclista - Critério Brasil - Classificação equivalente
# Ciclista - 3. Qual a sua renda familiar? (2)
# Ciclista – Classe da renda familiar
# Ciclista - 19. Com qual cor ou raça você se identifica?
# ...

# %% [markdown]
# ### List of columns that I want to analyse:
#
# Ciclista - 1. Qual a sua idade? <br>
# Ciclista - 2. Com qual gênero você se identifica?  <br>
# Ciclista - 3. Qual a sua renda familiar?  <br>
# Ciclista - 6. Automóvel <br>
# Ciclista - 14. Motocicleta <br>
# Ciclista - 17. Sua residência possui rua pavimentada?  <br>
# Ciclista - 18. Qual o seu grau de instrução atual?  <br>
# Ciclista - Critério Brasil - Pontos <br>
# Ciclista - Critério Brasil - Classe <br>
# Ciclista - Ciclista - Critério Brasil - Classificação equivalente <br>
# Ciclista - 3. Qual a sua renda familiar? (2) <br>
# Ciclista – Classe da renda familiar <br>
# Ciclista - 19. Com qual cor ou raça você se identifica?  <br>
# Ciclista - 20. Qual a quantidade de pessoas que moram na sua residência? (Caso more sozinho, assinalar valor igual a 01) <br>
# Ciclista - 21. Quantos veículos motorizados (Automóvel/Motocicleta) estão disponíveis na sua residência?  <br>
# Ciclista - 22. Quantas bicicletas estão disponíveis na sua residência?  <br>
# Ciclista - 23. Qual o bairro onde você reside?  <br>
# Ciclista - 23. Qual o bairro onde você reside? (Area Metro) <br>
# Ciclista - 23. Qual o bairro onde você reside? (Area SPTrans) <br>
# Ciclista - 24. Qual a sua condição (ocupação) de atividade atual?  <br>
# Ciclista - 25. Quantas vezes você costumava se deslocar por semana (de segunda a sexta-feira) antes da pandemia?  <br>
# Ciclista - 26. Qual o principal motivo dos seus deslocamentos antes da pandemia?  <br>
# Ciclista - 26.1 Qual o bairro onde você realizava essa atividade antes da pandemia?  <br>
# Ciclista - 26.1 Qual o bairro onde você realizava essa atividade antes da pandemia? (Area Metro) <br>
# Ciclista - 26.1 Qual o bairro onde você realizava essa atividade antes da pandemia? (Area SPTrans) <br>
# Ciclista - 27. Quanto tempo, em média, você costumava gastar para chegar à atividade principal indicada no item 12? (Hora) <br>
# Ciclista - 27. Quanto tempo, em média, você costumava gastar para chegar à atividade principal indicada no item 12? (Minuto) <br>
# Ciclista - 28. Para realizar a atividade indicada no item 12, quantos meios de transporte você costumava utilizar?  <br>
# Ciclista - 29. Qual o meio de transporte você costumava utilizar para realizar a atividade indicada no item 12 antes da pandemia?  <br>
# Ciclista - 30. (Modo de transporte principal) <br>
# 30. Quais os meios de transporte você costumava utilizar em uma única viagem para realizar a atividade indicada no item 11 antes da pandemia? - Seleção 1 <br>
# 30. Quais os meios de transporte você costumava utilizar em uma única viagem para realizar a atividade indicada no item 11 antes da pandemia? - Seleção 2 <br>
# Ciclista - 31. Quanto você costumava pagar para utilizar esse(s) meio(s) de transporte?  <br>
# Ciclista - 32. Qual o valor médio que você costumava pagar de estacionamento?  <br>
# Ciclista - 33. Qual o valor médio que você costumava pagar?  <br>
#
#
# [COLUNAS DOS CENÁRIOS (de 1 a 6)] <br>
#
# Ciclista - 34. Você usaria bicicleta se recebesse créditos monetários em forma de cartão de débito <br>
# Ciclista - 35. Você usaria mais a bicicleta se recebesse créditos monetários para a troca de bens e serviços <br>
# Ciclista - 36. Você usaria mais a bicicleta se recebesse créditos em contrapartidas por serviços públicos <br>
# Ciclista - 37. Você usaria mais a bicicleta se recebesse créditos que pudessem ser transferidos para a sua conta bancária/poupança <br>
# Ciclista - 38. Você usaria mais a bicicleta se recebesse créditos no Bilhete Único de transporte <br>
# Ciclista - 39. Você usaria mais a bicicleta se recebesse créditos para compra de medicamentos <br>
# Ciclista - Observações <br>

# %% [markdown]
# ### Comparar respostas nos cenários com perfis iniciais
#
# Ciclista - PD Cenário 1 (Ficha 1 - Tipo de ficha)  <br>
# Ciclista - PD Cenário 1 (Ficha 1 - Selecionado)  <br>
# Ciclista - PD Cenário 1 (Ficha 1 - Tempo de viagem (min)) <br>
# Ciclista - PD Cenário 1 (Ficha 1 - Tempo de Acesso (min)) <br>
# Ciclista - PD Cenário 1 (Ficha 1 - Tempo de Egresso (min)) <br>
# Ciclista - PD Cenário 1 (Ficha 1 - Custo (R$)) <br>
# Ciclista - PD Cenário 1 (Ficha 1 - Presenca de infraestrutura cicloviária) <br>
# Ciclista - PD Cenário 1 (Ficha 1 - Remuneracao Bike SP) <br>
# Ciclista - PD Cenário 1 (Ficha 1 - Estacionamento de bicicleta)  <br>
# Ciclista - PD Cenário 1 (Ficha 1 - Facilidades no destino)  <br>
# Ciclista - PD Cenário 1 (Ficha 2 - Tipo de ficha)  <br>
# Ciclista - PD Cenário 1 (Ficha 2 - Selecionado)  <br>
# Ciclista - PD Cenário 1 (Ficha 2 - Tempo de viagem (min))  <br>
# Ciclista - PD Cenário 1 (Ficha 2 - Tempo de Acesso (min))  <br>
# Ciclista - PD Cenário 1 (Ficha 2 - Tempo de Egresso (min))  <br>
# Ciclista - PD Cenário 1 (Ficha 2 - Custo (R$))  <br>
# Ciclista - PD Cenário 1 (Ficha 2 - Presenca de infraestrutura cicloviária)  <br>
# Ciclista - PD Cenário 1 (Ficha 2 - Remuneracao Bike SP)  <br>
# Ciclista - PD Cenário 1 (Ficha 2 - Estacionamento de bicicleta)  <br>
# Ciclista - PD Cenário 1 (Ficha 2 - Facilidades no destino)  <br>
# Ciclista - PD Cenário 1 (Ficha 3 - Tipo de ficha)  <br>
# Ciclista - PD Cenário 1 (Ficha 3 - Selecionado)  <br>
# Ciclista - PD Cenário 1 (Ficha 3 - Tempo de viagem (min))  <br>
# Ciclista - PD Cenário 1 (Ficha 3 - Tempo de Acesso (min))  <br>
# Ciclista - PD Cenário 1 (Ficha 3 - Tempo de Egresso (min))  <br>
# Ciclista - PD Cenário 1 (Ficha 3 - Custo (R$))  <br>
# Ciclista - PD Cenário 1 (Ficha 3 - Presenca de infraestrutura cicloviária)  <br>
# Ciclista - PD Cenário 1 (Ficha 3 - Remuneracao Bike SP)  <br>
# Ciclista - PD Cenário 1 (Ficha 3 - Estacionamento de bicicleta)  <br>
# Ciclista - PD Cenário 1 (Ficha 3 - Facilidades no destino)  <br>

# %% [markdown]
# ## Null values

# %%
column_name = 'Ciclista - PD Cenário 1 (Ficha 1 - Tipo de ficha)'
data.columns.get_loc(column_name)
# Out:
# 47

# %%
column_name = 'Ciclista - PD Cenário 6 (Ficha 3 - Facilidades no destino)'
data.columns.get_loc(column_name)
# Out:
# 226

# %%
column_name = 'Ciclista - 39. Você usaria mais a bicicleta se recebesse créditos para compra de medicamentos'
data.columns.get_loc(column_name)
# Out:
# 232

# %%
df1 = data.iloc[:,:47]
df2 = data.iloc[:,227:232]
data_selected = pd.concat([df1, df2], axis=1, join='inner')

# %%
data_selected = data_selected.drop(['Ciclista - 1. Qual a sua idade? (Faixa etária)',
                    'Ciclista - 4. Banheiro',
                    'Ciclista - 5. Empregado doméstico',
                    'Ciclista - 7. Microcomputador',
                    'Ciclista - 8. Lava louça',
                    'Ciclista - 9. Geladeira',
                    'Ciclista - 10. Freezer',
                    'Ciclista - 11. Lava roupa',
                    'Ciclista - 12. DVD',
                    'Ciclista - 13. Microondas',
                    'Ciclista - 15. Secadora de roupas',
                    'Ciclista - 16. Sua residência possui água encanada?',
                    'Ciclista - 17. Sua residência possui rua pavimentada?'], axis = 1)

# %%
null = pd.DataFrame()
null['count'] = data_selected.iloc[:,:47].isnull().sum()

# %%
null['count'][null['count'] != 0]
# Out:
# Ciclista – Classe da renda familiar                                                                                                                            31
# Ciclista - 29. Qual o meio de transporte você costumava utilizar para realizar a atividade indicada no item 12 antes da pandemia?                             177
# Ciclista - 30. (Modo de transporte principal)                                                                                                                 928
# 30. Quais os meios de transporte você costumava utilizar em uma única viagem para realizar a atividade indicada no item 11 antes da pandemia? - Seleção 1     928
# 30. Quais os meios de transporte você costumava utilizar em uma única viagem para realizar a atividade indicada no item 11 antes da pandemia? - Seleção 2     931
# Ciclista - 31. Quanto você costumava pagar para utilizar esse(s) meio(s) de transporte?                                                                      1063
# ...

# %% [markdown]
# ## Analysis of a single random person, to understand the data

# %%
person =  data._slice(slice(123,124)) # use slice instead of iloc to get a dataframe as result, not a series
person_selected = data_selected._slice(slice(123,124))
person_selected
# Out:
#      Ciclista - 1. Qual a sua idade?  \
# 123                               54
#
#     Ciclista - 2. Com qual gênero você se identifica?  \
# 123                                       2. Feminino
#
#     Ciclista - 3. Qual a sua renda familiar? Ciclista - 6. Automóvel  \
# 123                  3. R$ 4.181 a R$ 10.450                       0
#
#     Ciclista - 14. Motocicleta  \
# 123                          0
#
#     Ciclista - 18. Qual o seu grau de instrução atual?  \
# 123            4. Médio Completo / Superior incompleto
#
#      Ciclista - Critério Brasil - Pontos Ciclista - Critério Brasil - Classe  \
# 123                                   37                                  B2
#
#      Ciclista - Ciclista - Critério Brasil - Classificação equivalente  \
# 123                                            5721.72
#
#     Ciclista - 3. Qual a sua renda familiar? (2)  \
# 123                      3. R$ 4.181 a R$ 10.450
#
#     Ciclista – Classe da renda familiar  \
# ...

# %%
person_selected.columns[person_selected.isna().any()].tolist()
# Out:
# ['Ciclista - 29. Qual o meio de transporte você costumava utilizar para realizar a atividade indicada no item 12 antes da pandemia?',
#  'Ciclista - 31. Quanto você costumava pagar para utilizar esse(s) meio(s) de transporte?',
#  'Ciclista - 32. Qual o valor médio que você costumava pagar de estacionamento?',
#  'Ciclista - 33. Qual o valor médio que você costumava pagar?']

# %%
person
# Out:
#      Ciclista - 1. Qual a sua idade?  \
# 123                               54
#
#     Ciclista - 1. Qual a sua idade? (Faixa etária)  \
# 123                          2. Entre 19 e 60 anos
#
#     Ciclista - 2. Com qual gênero você se identifica?  \
# 123                                       2. Feminino
#
#     Ciclista - 3. Qual a sua renda familiar? Ciclista - 4. Banheiro  \
# 123                  3. R$ 4.181 a R$ 10.450                      1
#
#     Ciclista - 5. Empregado doméstico Ciclista - 6. Automóvel  \
# 123                                 0                       0
#
#     Ciclista - 7. Microcomputador  Ciclista - 8. Lava louça  \
# 123                             3                         0
#
#     Ciclista - 9. Geladeira Ciclista - 10. Freezer Ciclista - 11. Lava roupa  \
# 123                       2                      1                         2
#
#     Ciclista - 12. DVD  Ciclista - 13. Microondas Ciclista - 14. Motocicleta  \
# ...

# %%
def define_scenario_columns(scenario_number):
    scenario_columns_ficha1 = [f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Tipo de ficha)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Selecionado)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Tempo de viagem (min))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Tempo de Acesso (min))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Tempo de Egresso (min))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Custo (R$))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Presenca de infraestrutura cicloviária)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Remuneracao Bike SP)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Estacionamento de bicicleta)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Facilidades no destino)'.format(scenario_number = scenario_number),
    ]
    scenario_columns_ficha2 = [
        f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Tipo de ficha)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Selecionado)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Tempo de viagem (min))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Tempo de Acesso (min))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Tempo de Egresso (min))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Custo (R$))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Presenca de infraestrutura cicloviária)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Remuneracao Bike SP)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Estacionamento de bicicleta)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Facilidades no destino)'.format(scenario_number = scenario_number),
    ]
    scenario_columns_ficha3 = [
        f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Tipo de ficha)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Selecionado)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Tempo de viagem (min))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Tempo de Acesso (min))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Tempo de Egresso (min))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Custo (R$))'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Presenca de infraestrutura cicloviária)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Remuneracao Bike SP)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Estacionamento de bicicleta)'.format(scenario_number = scenario_number),
        f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Facilidades no destino)'.format(scenario_number = scenario_number),
    ]
    return scenario_columns_ficha1, scenario_columns_ficha2, scenario_columns_ficha3

# %%
pd.set_option('display.max_columns', None)

# %%
scenario_number = '1'
scenario_columns_ficha1, scenario_columns_ficha2, scenario_columns_ficha3 = define_scenario_columns(scenario_number)

display(person[scenario_columns_ficha1])
display(person[scenario_columns_ficha2])
display(person[scenario_columns_ficha3])
# Out:
#     Ciclista - PD Cenário 1 (Ficha 1 - Tipo de ficha)  \
# 123                                        modo_atual
#
#     Ciclista - PD Cenário 1 (Ficha 1 - Selecionado)  \
# 123                                 Não selecionado
#
#     Ciclista - PD Cenário 1 (Ficha 1 - Tempo de viagem (min))  \
# 123                                             27 min
#
#      Ciclista - PD Cenário 1 (Ficha 1 - Tempo de Acesso (min))  \
# 123                                                NaN
#
#      Ciclista - PD Cenário 1 (Ficha 1 - Tempo de Egresso (min))  \
# 123                                                NaN
#
#     Ciclista - PD Cenário 1 (Ficha 1 - Custo (R$))  \
# 123                                        R$ 7,65
#
#      Ciclista - PD Cenário 1 (Ficha 1 - Presenca de infraestrutura cicloviária)  \
# 123                                                NaN
#
#      Ciclista - PD Cenário 1 (Ficha 1 - Remuneracao Bike SP)  \
# 123                                                NaN
#
# ...

# %%
scenario_number = '2'
scenario_columns_ficha1, scenario_columns_ficha2, scenario_columns_ficha3 = define_scenario_columns(scenario_number)

display(person[scenario_columns_ficha1])
display(person[scenario_columns_ficha2])
display(person[scenario_columns_ficha3])
# Out:
#     Ciclista - PD Cenário 2 (Ficha 1 - Tipo de ficha)  \
# 123                                        modo_atual
#
#     Ciclista - PD Cenário 2 (Ficha 1 - Selecionado)  \
# 123                                 Não selecionado
#
#     Ciclista - PD Cenário 2 (Ficha 1 - Tempo de viagem (min))  \
# 123                                             27 min
#
#      Ciclista - PD Cenário 2 (Ficha 1 - Tempo de Acesso (min))  \
# 123                                                NaN
#
#      Ciclista - PD Cenário 2 (Ficha 1 - Tempo de Egresso (min))  \
# 123                                                NaN
#
#     Ciclista - PD Cenário 2 (Ficha 1 - Custo (R$))  \
# 123                                        R$ 7,65
#
#      Ciclista - PD Cenário 2 (Ficha 1 - Presenca de infraestrutura cicloviária)  \
# 123                                                NaN
#
#      Ciclista - PD Cenário 2 (Ficha 1 - Remuneracao Bike SP)  \
# 123                                                NaN
#
# ...

# %%
scenario_number = '3'
scenario_columns_ficha1, scenario_columns_ficha2, scenario_columns_ficha3 = define_scenario_columns(scenario_number)

display(person[scenario_columns_ficha1])
display(person[scenario_columns_ficha2])
display(person[scenario_columns_ficha3])
# Out:
#     Ciclista - PD Cenário 3 (Ficha 1 - Tipo de ficha)  \
# 123                                        modo_atual
#
#     Ciclista - PD Cenário 3 (Ficha 1 - Selecionado)  \
# 123                                 Não selecionado
#
#     Ciclista - PD Cenário 3 (Ficha 1 - Tempo de viagem (min))  \
# 123                                             27 min
#
#      Ciclista - PD Cenário 3 (Ficha 1 - Tempo de Acesso (min))  \
# 123                                                NaN
#
#      Ciclista - PD Cenário 3 (Ficha 1 - Tempo de Egresso (min))  \
# 123                                                NaN
#
#     Ciclista - PD Cenário 3 (Ficha 1 - Custo (R$))  \
# 123                                        R$ 7,65
#
#      Ciclista - PD Cenário 3 (Ficha 1 - Presenca de infraestrutura cicloviária)  \
# 123                                                NaN
#
#      Ciclista - PD Cenário 3 (Ficha 1 - Remuneracao Bike SP)  \
# 123                                                NaN
#
# ...

# %%
ficha2_df = data[scenario_columns_ficha2]
ficha2_df
# Out:
#      Ciclista - PD Cenário 3 (Ficha 2 - Tipo de ficha)  \
# 0                                    bicicleta_propria
# 1                                    bicicleta_propria
# 2                                    bicicleta_propria
# 3                                    bicicleta_propria
# 4                                    bicicleta_propria
# ...                                                ...
# 1104                                 bicicleta_propria
# 1105                                 bicicleta_propria
# 1106                                 bicicleta_propria
# 1107                                 bicicleta_propria
# 1108                                 bicicleta_propria
#
#      Ciclista - PD Cenário 3 (Ficha 2 - Selecionado)  \
# 0                                    Não selecionado
# 1                                    Não selecionado
# 2                                    Não selecionado
# 3                                        Selecionado
# ...

# %%
ficha2_df = data[data['Ciclista - PD Cenário 3 (Ficha 2 - Presenca de infraestrutura cicloviária)'].isnull() == False][scenario_columns_ficha2]
ficha2_df
# Out:
#      Ciclista - PD Cenário 3 (Ficha 2 - Tipo de ficha)  \
# 0                                    bicicleta_propria
# 1                                    bicicleta_propria
# 2                                    bicicleta_propria
# 3                                    bicicleta_propria
# 4                                    bicicleta_propria
# ...                                                ...
# 1104                                 bicicleta_propria
# 1105                                 bicicleta_propria
# 1106                                 bicicleta_propria
# 1107                                 bicicleta_propria
# 1108                                 bicicleta_propria
#
#      Ciclista - PD Cenário 3 (Ficha 2 - Selecionado)  \
# 0                                    Não selecionado
# 1                                    Não selecionado
# 2                                    Não selecionado
# 3                                        Selecionado
# ...

# %%
ficha2_df.groupby(scenario_columns_ficha2).size().reset_index().rename(columns={0:'count'})
# Out:
# Empty DataFrame
# Columns: [Ciclista - PD Cenário 3 (Ficha 2 - Tipo de ficha), Ciclista - PD Cenário 3 (Ficha 2 - Selecionado), Ciclista - PD Cenário 3 (Ficha 2 - Tempo de viagem (min)), Ciclista - PD Cenário 3 (Ficha 2 - Tempo de Acesso (min)), Ciclista - PD Cenário 3 (Ficha 2 - Tempo de Egresso (min)), Ciclista - PD Cenário 3 (Ficha 2 - Custo (R$)), Ciclista - PD Cenário 3 (Ficha 2 - Presenca de infraestrutura cicloviária), Ciclista - PD Cenário 3 (Ficha 2 - Remuneracao Bike SP), Ciclista - PD Cenário 3 (Ficha 2 - Estacionamento de bicicleta), Ciclista - PD Cenário 3 (Ficha 2 - Facilidades no destino), count]
# Index: []

# %%
ficha2_df.groupby(['Ciclista - PD Cenário 3 (Ficha 2 - Selecionado)']).size().reset_index().rename(columns={0:'count'})
# Out:
#   Ciclista - PD Cenário 3 (Ficha 2 - Selecionado)  count
# 0                                 Não selecionado    679
# 1                                     Selecionado    430

# %%
scenario_columns_ficha2
# Out:
# ['Ciclista - PD Cenário 3 (Ficha 2 - Tipo de ficha)',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Selecionado)',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Tempo de viagem (min))',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Tempo de Acesso (min))',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Tempo de Egresso (min))',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Custo (R$))',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Presenca de infraestrutura cicloviária)',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Remuneracao Bike SP)',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Estacionamento de bicicleta)',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Facilidades no destino)']

# %%
remove_columns = ('Ciclista - PD Cenário 3 (Ficha 2 - Selecionado)',
                  'Ciclista - PD Cenário 3 (Ficha 2 - Tempo de viagem (min))',
                  'Ciclista - PD Cenário 3 (Ficha 2 - Tempo de Acesso (min))',
                    'Ciclista - PD Cenário 3 (Ficha 2 - Tempo de Egresso (min))',
                    'Ciclista - PD Cenário 3 (Ficha 2 - Custo (R$))',
                    'Ciclista - PD Cenário 3 (Ficha 2 - Remuneracao Bike SP)',)
scenario_columns_ficha2_selected = [e for e in scenario_columns_ficha2 if e not in remove_columns]

# %%
def define_scenario_columns_selected(scenario_number):
    scenario_columns_fichas = [f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Tipo de ficha)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Custo (R$))'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Presenca de infraestrutura cicloviária)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Estacionamento de bicicleta)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 1 - Facilidades no destino)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Tipo de ficha)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Custo (R$))'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Presenca de infraestrutura cicloviária)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Estacionamento de bicicleta)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 2 - Facilidades no destino)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Tipo de ficha)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Custo (R$))'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Presenca de infraestrutura cicloviária)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Estacionamento de bicicleta)'.format(scenario_number = scenario_number),
    f'Ciclista - PD Cenário {scenario_number} (Ficha 3 - Facilidades no destino)'.format(scenario_number = scenario_number)]
    return scenario_columns_fichas

# %%
scenario_columns_selected = define_scenario_columns_selected('1') + define_scenario_columns_selected('2') + define_scenario_columns_selected('3') + define_scenario_columns_selected('4') + define_scenario_columns_selected('5') + define_scenario_columns_selected('6')

# %%
scenario_columns_ficha2_selected
# Out:
# ['Ciclista - PD Cenário 3 (Ficha 2 - Tipo de ficha)',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Presenca de infraestrutura cicloviária)',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Estacionamento de bicicleta)',
#  'Ciclista - PD Cenário 3 (Ficha 2 - Facilidades no destino)']

# %%
ficha2_df
# Out:
#      Ciclista - PD Cenário 3 (Ficha 2 - Tipo de ficha)  \
# 0                                    bicicleta_propria
# 1                                    bicicleta_propria
# 2                                    bicicleta_propria
# 3                                    bicicleta_propria
# 4                                    bicicleta_propria
# ...                                                ...
# 1104                                 bicicleta_propria
# 1105                                 bicicleta_propria
# 1106                                 bicicleta_propria
# 1107                                 bicicleta_propria
# 1108                                 bicicleta_propria
#
#      Ciclista - PD Cenário 3 (Ficha 2 - Selecionado)  \
# 0                                    Não selecionado
# 1                                    Não selecionado
# 2                                    Não selecionado
# 3                                        Selecionado
# ...

# %%
data_without_null = data.fillna('None')

# %%
data_without_null[scenario_columns_selected].groupby(scenario_columns_selected).size().reset_index().rename(columns={0:'count'})
# Out:
#     Ciclista - PD Cenário 1 (Ficha 1 - Tipo de ficha)  \
# 0                                          modo_atual
# 1                                          modo_atual
# 2                                          modo_atual
# 3                                          modo_atual
# 4                                          modo_atual
# ..                                                ...
# 343                                        modo_atual
# 344                                        modo_atual
# 345                                        modo_atual
# 346                                        modo_atual
# 347                                        modo_atual
#
#     Ciclista - PD Cenário 1 (Ficha 1 - Custo (R$))  \
# 0                                             R$ -
# 1                                             R$ -
# 2                                             R$ -
# 3                                             R$ -
# 4                                             R$ -
# ...

# %%
ficha2_df.groupby(scenario_columns_ficha2_selected).size().reset_index().rename(columns={0:'count'})
# Out:
#   Ciclista - PD Cenário 3 (Ficha 2 - Tipo de ficha)  \
# 0                                 bicicleta_propria
# 1                                 bicicleta_propria
# 2                                 bicicleta_propria
# 3                                 bicicleta_propria
# 4                                 bicicleta_propria
#
#   Ciclista - PD Cenário 3 (Ficha 2 - Presenca de infraestrutura cicloviária)  \
# 0                                         Ciclofaixa
# 1                                         Ciclofaixa
# 2                                           Ciclovia
# 3                                       Sem Ciclovia
# 4                                       Sem Ciclovia
#
#   Ciclista - PD Cenário 3 (Ficha 2 - Estacionamento de bicicleta)  \
# 0                     Bicicletário sem monitoramento
# 1                                   Sem bicicletário
# 2                     Bicicletário sem monitoramento
# 3                     Bicicletário sem monitoramento
# ...

# %%
data['Ciclista - PD Cenário 1 (Ficha 3 - Custo (R$))'].unique()
# Out:
# array(['R$2.00', 'R$1.50', '$1.00'], dtype=object)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We have to find an alternative way to find out to which scenario each individual belongs.
